# %% [markdown]
# # Interpreting BERT Models through email

# %%
# !nvidia-smi

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install datasets huggingface_hub 
# !pip install git+https://github.com/huggingface/transformers
# !pip install transformers==4.27.0
# !pip install evaluate
# !pip install lime

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from transformers import BertTokenizer, BertForQuestionAnswering, BertConfig

import torch
from torch.utils.data.dataloader import DataLoader

from transformers import AutoConfig, AutoModelForSequenceClassification, AutoTokenizer, EvalPrediction, GlueDataset
from transformers import AutoTokenizer, AutoModel, AutoModelWithLMHead
from transformers import GlueDataTrainingArguments as DataTrainingArguments


import lime
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2"
torch.cuda.empty_cache()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# %%
torch.cuda.device_count()
# Out:
# 3

# %%
# for i in range(3):
#     print(torch.cuda.get_device_name(i))
#     print('Memory Usage:')
#     print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#     print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')

# %% [markdown]
# The first step is to fine-tune BERT model on SQUAD dataset. This can be easiy accomplished by following the steps described in hugging face's official web site: https://github.com/huggingface/transformers#run_squadpy-fine-tuning-on-squad-for-question-answering
#
# Note that the fine-tuning is done on a `bert-base-uncased` pre-trained model.

# %% [markdown]
# After we pretrain the model, we can load the tokenizer and pre-trained BERT model using the commands described below.

# %%
# replace <PATH-TO-SAVED-MODEL> with the real path of the saved model
model_path = 'randellcotta/distilbert-base-uncased-finetuned-yelp-polarity'

# load model
model = AutoModelForSequenceClassification.from_pretrained(model_path)

# parallelising
model=nn.DataParallel(model)
model.to(device)
model.eval()
model.zero_grad()

# load tokenizer
tokenizer=AutoTokenizer.from_pretrained(model_path)

# %% [markdown]
# # Data loading and tokenization

# %%
question_neg, text_neg = "Unfortunately, the frustration of being Dr. Goldberg's patient is a repeat of the experience I've had with so many other doctors in NYC -- good doctor, terrible staff. It seems that his staff simply never answers the phone. It usually takes 2 hours of repeated calling to get an answer. Who has time for that or wants to deal with it? I have run into this problem with many other doctors and I just don't get it. You have office workers, you have patients with medical needs, why isn't anyone answering the phone? It's incomprehensible and not work the aggravation. It's with regret that I feel that I have to give Dr. Goldberg 2 stars.", '0'
question_pos, text_pos = "Before I finally made it over to this range I heard the same thing from most people - it's just fine to go work on your swing. I had such a low expectation I was pleasantly surprised. \n\nIt's a fairly big range - if you are familiar with Scally's in Moon, it seems like it has almost as many tees, though its not nearly as nice a facility. \n\nThe guys in the pro shop were two of the friendlier guys I've come across at ranges or at courses. Yards were indeed marked and there are some targets to aim for, and even some hazards to aim away from. \n\nA big red flag to me was the extra charge ($3) to hit off the grass. I am no range expert, but this is the 4th one I've been to and the first I've seen of that sort of nickel and diming....\n\nPrice for the golf balls was reasonable and I do plan to be back every week until they close up in October for the season. Hopefully, since its for sale, it will reopen as a golf facility again.",'1'

# %%
tokenized_stuff_neg=tokenizer.encode(question_neg,add_special_tokens=False,return_tensors='pt').to(device)
tokenized_stuff_pos=tokenizer.encode(question_pos,add_special_tokens=False,return_tensors='pt').to(device)

# %%
with torch.no_grad():
    out_neg = model(input_ids=tokenized_stuff_neg.to(device))
    out_pos = model(input_ids=tokenized_stuff_pos.to(device))

# %%
print("Negative Sample Prediction ", out_neg)
print("Positive Sample Prediction ", out_pos)
# Out:
# Negative Sample Prediction  SequenceClassifierOutput(loss=<generator object gather.<locals>.gather_map.<locals>.<genexpr> at 0x7ff4d5e43970>, logits=tensor([[ 3.5445, -3.7237]], device='cuda:0'), hidden_states=None, attentions=None)
# Positive Sample Prediction  SequenceClassifierOutput(loss=<generator object gather.<locals>.gather_map.<locals>.<genexpr> at 0x7ff4d5e43820>, logits=tensor([[-1.7218,  1.5928]], device='cuda:0'), hidden_states=None, attentions=None)

# %% [markdown]
# # Using LIME toolbox for LIME

# %%
# from lime.lime_text import LimeTextExplainer
# explainer = LimeTextExplainer(class_names=['Negative','Positive'])

# %%
# hello=tokenizer(question_neg,return_tensors='pt',padding=True).to(device)

# %%
# hello

# %%
def fun_predict(question_pos):
  out_pos = model(**tokenizer(question_pos,return_tensors='pt',padding=True).to(device))
  out_pos=out_pos[0].to(device)
  classfn_out_pos=torch.softmax(out_pos,dim=1).detach().cpu().numpy()
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_pos

# %%
# torch.cuda.memory_allocated(2)

# %%
# fun_predict(question_pos)

# %%
# exp = explainer.explain_instance(question_pos,fun_predict, num_samples=1000,num_features=100)

# %%
# exp.show_in_notebook(text=question_pos)

# %%
# exp.as_list()

# %%
# def fun_predict(question_pos):
#   out_neg = model(**tokenizer(question_pos,return_tensors='pt',padding=True,truncation=True).to(device))
#   out_neg=out_neg[0].to(device)
#   classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
# #   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
# #   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
#   return classfn_out_neg

# %%
# torch.cuda.memory_allocated(2)

# %%
# fun_predict(question_neg)

# %%
# exp = explainer.explain_instance(question_neg,fun_predict, num_samples=200,num_features=100)

# %%
# exp.show_in_notebook(text=question_neg)

# %%
# exp.as_list()

# %% [markdown]
# # Running with the Yelp + SST data

# %%
# %cd Spurious_Correlations-20230425T172048Z-001/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models/
# %cd /content/drive/MyDrive/CMSC848D_Project/Spurious_Correlations-20230425T172048Z-001/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models
# Out:
# /home/harduin/Desktop/Research/CMSC848D_Project/Spurious_Correlations-20230425T172048Z-001/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models

# %%
import utils.data_structure as dataproj

# %%
df_yelp=dataproj.get_yelp()
df_sst2=dataproj.get_sst2()
# Out:
# Found cached dataset yelp_polarity (/home/harduin/.cache/huggingface/datasets/yelp_polarity/plain_text/1.0.0/14f90415c754f47cf9087eadac25823a395fef4400c7903c5897f55cfaaa6f61)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Found cached dataset glue (/home/harduin/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from lime.lime_text import LimeTextExplainer
explainer = LimeTextExplainer(class_names=['Negative','Positive'])

# %%
df_yelp['text'][0]
# Out:
# "Contrary to other reviews, I have zero complaints about the service or the prices. I have been getting tire service here for the past 5 years now, and compared to my experience with places like Pep Boys, these guys are experienced and know what they're doing. \\nAlso, this is one place that I do not feel like I am being taken advantage of, just because of my gender. Other auto mechanics have been notorious for capitalizing on my ignorance of cars, and have sucked my bank account dry. But here, my service and road coverage has all been well explained - and let up to me to decide. \\nAnd they just renovated the waiting room. It looks a lot better than it did in previous years."

# %%
# exp = explainer.explain_instance(df_yelp['text'][0],fun_predict, num_samples=1000,num_features=100)

# %%
# import time

# word2id=dict()
# id2word=dict()

# idx_sentence=0

# for idx in range(df_yelp.shape[0]):
#     start=time.time()
#     exp = explainer.explain_instance(df_yelp['text'][idx],fun_predict, num_samples=500,num_features=100)
#     out=exp.as_list()
# #     for i in out:
# #         id2word[idx]=i[0]
# #         print(id2word)
# #     print("ONE INDEX")
        
# # print(id2word)
#     for i in out:
#         id2word[idx]=i[0]
# #         print("ID2WORD \n \n",id2word)
# #         print("Word : ", i[0])
# #         print("Value : ", i[1])
#         if (i[0] in word2id.keys()):
# #             print("APPEND")
# #             print("##################### DEBUG ###################")
# #             print("word2id[i[0]][0] ", word2id[i[0]][0])
# #             print("word2id[i[0]][1] ",word2id[i[0]][1])
# #             print("##################### DEBUG ###################")
#             word2id[i[0]][0].append(i[1])
#             word2id[i[0]][1].append(idx)
#         else:
# #             print("CREATE")
#             word2id[i[0]]=[[],[]]
#             word2id[i[0]][0].append(i[1])
#             word2id[i[0]][1].append(idx)
#     end=time.time()
#     print("Index : ",idx, " Time elapsed : ",end-start)
# #         print("Word2ID \n \n",word2id)
# #         print(word2id)
# #     print("One index finished \n \n \n")

# print(id2word)
# print(word2id)
# # print(len(list(word2id.keys())))



# # print(len(out))
    
# # word2id.keys()



# # x=pd.DataFrame(columns=['word','value'])
# # for i in range(df_yelp.shape[0]):
# #     exp = explainer.explain_instance(df_yelp['text'][i],fun_predict, num_samples=1000,num_features=100)
# #     print(exp.as_list())
# #     print('\n')
# #     print('\n')
# #     print('\n')
# #     df=pd.DataFrame(exp.as_list(),columns=['train_idx','word','value'])
# # #     print(count)
# #     if i==5:
# #         break
# # # count

# %%
# word2id

# %%
# import pickle
# with open('saved_word2id.pkl','wb') as f:
#     pickle.dump(word2id,f)
# with open('saved_id2word.pkl','wb') as g:
#     pickle.dump(id2word,g)

# %%
# len(set(word2id.keys()))

# %%
# with open('saved_word2id.pkl', 'rb') as f:
#     x = pickle.load(f)
# print(x)

# %%
# import time

# word2id=dict()
# id2word=dict()

# idx_sentence=0

# for idx in range(df_yelp.shape[0]):
#     start=time.time()
#     exp = explainer.explain_instance(df_yelp['text'][idx],fun_predict, num_samples=250,num_features=51)
#     out=exp.as_list()
# #     for i in out:
# #         id2word[idx]=i[0]
# #         print(id2word)
# #     print("ONE INDEX")
        
# # print(id2word)
#     for i in out:
#         id2word[idx]=i[0]
# #         print("ID2WORD \n \n",id2word)
# #         print("Word : ", i[0])
# #         print("Value : ", i[1])
#         if (i[0] in word2id.keys()):
# #             print("APPEND")
# #             print("##################### DEBUG ###################")
# #             print("word2id[i[0]][0] ", word2id[i[0]][0])
# #             print("word2id[i[0]][1] ",word2id[i[0]][1])
# #             print("##################### DEBUG ###################")
#             word2id[i[0]][0].append(i[1])
#             word2id[i[0]][1].append(idx)
#         else:
# #             print("CREATE")
#             word2id[i[0]]=[[],[]]
#             word2id[i[0]][0].append(i[1])
#             word2id[i[0]][1].append(idx)
#     end=time.time()
#     print("Index : ",idx, " Time elapsed : ",end-start)
# #         print("Word2ID \n \n",word2id)
# #         print(word2id)
# #     print("One index finished \n \n \n")

# print(id2word)
# print(word2id)

# %% [markdown]
# # Captum implementation

# %%
# !pip install captum

# %%
from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_stuff_pos, target=0, n_samples=10000,show_progress=True)

# %%
# attr

# %%
# attr[0].shape

# %%
# !pip install nltk

# %%
# Other way of visualizing

# from IPython.core.display import HTML, display
# # import nltk
# # nltk.download('punkt')
# def show_text_attr(attrs):
#     rgb = lambda x: '255,0,0' if x < 0 else '0,255,0'
#     alpha = lambda x: abs(x) ** 0.5
#     # for token, attr in zip(tokenizer(question_pos), attrs.tolist()):
#     #   print(attr) 
#     token_marks = [
#         f'<mark style="background-color:rgba({rgb(attr)},{alpha(attr)})">{token}</mark>'
#         for token, attr in zip(tokenizer.convert_ids_to_tokens(tokenized_stuff_pos[0].detach().tolist()), attrs.tolist())
#     ]
#     # print(token_marks)
#     display(HTML('<p>' + ' '.join(token_marks) + '</p>'))
    
# show_text_attr(attr[0])

# %%
# print(attr.shape)
# print(tokenized_stuff_neg.shape)
# print(attr)

# %%
temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# %%
from captum.attr import visualization as viz

indices = tokenized_stuff_neg[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
# print(attr)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_stuff_neg)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_stuff_neg)[0])
ground_label=0
last_arg=0

# def summarize_attributions(attributions):
#     attributions = attributions.sum(dim=-1).squeeze(0)
#     attributions = attributions / torch.norm(attributions)
#     # print(attributions)
#     return attributions

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])

# %%
# # indices = tokenized_stuff_pos[0].detach().tolist()
# # all_tokens = tokenizer.convert_ids_to_tokens(indices)
# x=df_yelp['label'].astype(np.int8)
# type(x[0])

# %%
# model

# %%
# from captum.attr import Lime
# from captum._utils.models.linear_model import SkLearnLasso
# import time
# for idx in range(df_yelp.shape[0]):
#     start=time.time()
#     lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.01))
#     encoded_text=tokenizer.encode(df_yelp['text'][idx],add_special_tokens=False,truncation=True,padding=True,return_tensors='pt').to(device)
#     label_text=df_yelp['label'][idx].astype(np.int8)
#     attr = lime.attribute(encoded_text, target=1, n_samples=2000,show_progress=True)
# #     out=exp.as_list()
#     end=time.time()
#     print("Index : ",idx, " Time elapsed : ",end-start)

# %% [markdown]
# # Visualizing for the report

# %%
# Define the sample from the dataset

import utils.data_structure as ds

df_yelp=ds.get_yelp()
df_sst=ds.get_sst2()
df_movie_rationales=ds.get_movie_rationales()
# Out:
# Found cached dataset yelp_polarity (/home/harduin/.cache/huggingface/datasets/yelp_polarity/plain_text/1.0.0/14f90415c754f47cf9087eadac25823a395fef4400c7903c5897f55cfaaa6f61)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Found cached dataset glue (/home/harduin/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Found cached dataset movie_rationales (/home/harduin/.cache/huggingface/datasets/movie_rationales/default/0.1.0/70ed6b72496c90835e8ee73ebf8d0e49f5ad3aa93f302c8a4b6c886143cfb779)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
sentences_yelp=df_yelp['text']
labels_yelp=df_yelp['label']

sentences_sst=df_sst['text']
labels_sst=df_sst['label']

sentences_mr=df_movie_rationales['text']
labels_mr=df_movie_rationales['label']

idx=2017

sentence=sentences_yelp[idx]
label=labels_yelp[idx]

tokenized_sentence=tokenizer.encode(sentence,add_special_tokens=False,padding=True,truncation=True,return_tensors='pt').to(device)

# %%
# Compute LIME attribution : 5000

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=5000,show_progress=True)
# Out:
# Lime attribution:   0%|          | 0/5000 [00:00<?, ?it/s]
# /home/harduin/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/_utils/models/linear_model/train.py:327: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   sklearn_model.fit(x, y, sample_weight=w, **fit_kwargs)
# /home/harduin/miniconda3/envs/spurious_project/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /home/harduin/miniconda3/envs/spurious_project/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+02, tolerance: 3.305e-02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# %%
# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])
# Out:
#  Visualizations For Start Position
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>85.50</b></text></td><td><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> dirty                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 65%); opacity:1.0;                     line-height:1.75"><font color="black"> \                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> n                    </font></mark><mark style="background-color: hsl(120, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> \                    </font></mark><mark style="background-color: hsl(0, 75%, 76%); opacity:1.0;                     line-height:1.75"><font color="black"> nas                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> soon                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(0, 75%, 72%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 79%); opacity:1.0;                     line-height:1.75"><font color="black"> walk                    </font></mark><mark style="background-color: hsl(0, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> in                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> this                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> place                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> you        ...
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (1.00)</b></text></td><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>85.50</b></text></td><td><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> dirty                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> !                    </font></mark><mark style="background-color: hsl(120, 75%, 65%); opacity:1.0;                     line-height:1.75"><font color="black"> \                    </font></mark><mark style="background-color: hsl(0, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> n                    </font></mark><mark style="background-color: hsl(120, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> \                    </font></mark><mark style="background-color: hsl(0, 75%, 76%); opacity:1.0;                     line-height:1.75"><font color="black"> nas                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> soon                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(0, 75%, 72%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(0, 75%, 79%); opacity:1.0;                     line-height:1.75"><font color="black"> walk                    </font></mark><mark style="background-color: hsl(0, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> in                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> to                    </font></mark><mark style="background-color: hsl(120, 75%, 50%); opacity:1.0;                     line-height:1.75"><font color="black"> this                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> place                    </font></mark><mark style="background-color: hsl(0, 75%, 60%); opacity:1.0;                     line-height:1.75"><font color="black"> you        ...

# %%
# Compute LIME attribution : 100

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=100,show_progress=True)

temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])
# Out:
# Lime attribution:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 20
#      17   return classfn_out_neg
#      19 lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
# ---> 20 attr = lime.attribute(tokenized_sentence, target=10, n_samples=100,show_progress=True)
#      22 temp=attr[0].clone()
#      23 for i in range(len(temp)):
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/log/__init__.py:42, in log_usage.<locals>._log_usage.<locals>.wrapper(*args, **kwargs)
#      40 @wraps(func)
#      41 def wrapper(*args, **kwargs):
# ---> 42     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/attr/_core/lime.py:1067, in Lime.attribute(self, inputs, baselines, target, additional_forward_args, feature_mask, n_samples, perturbations_per_eval, return_input_shape, show_progress)
#     837 @log_usage()
#     838 def attribute(  # type: ignore
#     839     self,
#    (...)
#     848     show_progress: bool = False,
#     849 ) -> TensorOrTupleOfTensorsGeneric:
#     850     r"""
#     851     This method attributes the output of the model with given target index
#     852     (in case it is provided, otherwise it assumes that output is a
#    (...)
#    1065         >>> attr = lime.attribute(input, target=1, feature_mask=feature_mask)
#    1066     """
# -> 1067     return self._attribute_kwargs(
#    1068         inputs=inputs,
#    1069         baselines=baselines,
#    1070         target=target,
#    1071         additional_forward_args=additional_forward_args,
#    1072         feature_mask=feature_mask,
#    1073         n_samples=n_samples,
#    1074         perturbations_per_eval=perturbations_per_eval,
#    1075         return_input_shape=return_input_shape,
#    1076         show_progress=show_progress,
#    1077     )
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/attr/_core/lime.py:1178, in Lime._attribute_kwargs(self, inputs, baselines, target, additional_forward_args, feature_mask, n_samples, perturbations_per_eval, return_input_shape, show_progress, **kwargs)
#    1172     else:
#    1173         assert perturbations_per_eval == 1, (
#    1174             "Perturbations per eval must be 1 when forward function"
#    1175             "returns single value per batch!"
#    1176         )
# -> 1178 coefs = super().attribute.__wrapped__(
#    1179     self,
#    1180     inputs=inputs,
#    1181     target=target,
#    1182     additional_forward_args=additional_forward_args,
#    1183     n_samples=n_samples,
#    1184     perturbations_per_eval=perturbations_per_eval,
#    1185     baselines=baselines if is_inputs_tuple else baselines[0],
#    1186     feature_mask=feature_mask if is_inputs_tuple else feature_mask[0],
#    1187     num_interp_features=num_interp_features,
#    1188     show_progress=show_progress,
#    1189     **kwargs,
#    1190 )
#    1191 if return_input_shape:
#    1192     return self._convert_output_shape(
#    1193         formatted_inputs,
#    1194         feature_mask,
#    (...)
#    1197         is_inputs_tuple,
#    1198     )
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/attr/_core/lime.py:483, in LimeBase.attribute(self, inputs, target, additional_forward_args, n_samples, perturbations_per_eval, show_progress, **kwargs)
#     480 if expanded_target is None:
#     481     expanded_target = _expand_target(target, len(curr_model_inputs))
# --> 483 model_out = self._evaluate_batch(
#     484     curr_model_inputs,
#     485     expanded_target,
#     486     expanded_additional_args,
#     487     device,
#     488 )
#     490 if show_progress:
#     491     attr_progress.update()
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/attr/_core/lime.py:539, in LimeBase._evaluate_batch(self, curr_model_inputs, expanded_target, expanded_additional_args, device)
#     532 def _evaluate_batch(
#     533     self,
#     534     curr_model_inputs: List[TensorOrTupleOfTensorsGeneric],
#    (...)
#     537     device: torch.device,
#     538 ):
# --> 539     model_out = _run_forward(
#     540         self.forward_func,
#     541         _reduce_list(curr_model_inputs),
#     542         expanded_target,
#     543         expanded_additional_args,
#     544     )
#     545     if isinstance(model_out, Tensor):
#     546         assert model_out.numel() == len(curr_model_inputs), (
#     547             "Number of outputs is not appropriate, must return "
#     548             "one output per perturbed input"
#     549         )
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/_utils/common.py:487, in _run_forward(forward_func, inputs, target, additional_forward_args)
#     480 additional_forward_args = _format_additional_forward_args(additional_forward_args)
#     482 output = forward_func(
#     483     *(*inputs, *additional_forward_args)
#     484     if additional_forward_args is not None
#     485     else inputs
#     486 )
# --> 487 return _select_targets(output, target)
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/_utils/common.py:498, in _select_targets(output, target)
#     496 device = output.device
#     497 if isinstance(target, (int, tuple)):
# --> 498     return _verify_select_column(output, target)
#     499 elif isinstance(target, torch.Tensor):
#     500     if torch.numel(target) == 1 and isinstance(target.item(), int):
#
# File ~/miniconda3/envs/spurious_project/lib/python3.9/site-packages/captum/_utils/common.py:548, in _verify_select_column(output, target)
#     544 target = (target,) if isinstance(target, int) else target
#     545 assert (
#     546     len(target) <= len(output.shape) - 1
#     547 ), "Cannot choose target column with output shape %r." % (output.shape,)
# --> 548 return output[(slice(None), *target)]
#
# IndexError: index 10 is out of bounds for dimension 1 with size 2

# %%
# Compute LIME attribution : 500

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=500,show_progress=True)

temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])

# %%
# Compute LIME attribution : 1000

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=1000,show_progress=True)

temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])

# %%
# Compute LIME attribution : 2500

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=2500,show_progress=True)

temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])

# %%
# Compute LIME attribution : 10000

from captum.attr import Lime
from captum._utils.models.linear_model import SkLearnLasso

def fun_predict_captum(tokenized_stuff_pos):
  out_neg = model(tokenized_stuff_pos)
  # print(out_neg[0])
  out_neg=out_neg[0].to(device)
  # print(out_neg)
  # print(device)
  # classfn_out_neg=torch.softmax(out_neg,dim=1).detach().cpu().numpy()
  classfn_out_neg=torch.softmax(out_neg,dim=1)
  # print(classfn_out_neg)
#   print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
#   print('Cached:   ', round(torch.cuda.memory_cached(0)/1024**3,1), 'GB')
  return classfn_out_neg

lime = Lime(fun_predict_captum,interpretable_model=SkLearnLasso(alpha=0.0))
attr = lime.attribute(tokenized_sentence, target=1, n_samples=10000,show_progress=True)

temp=attr[0].clone()
for i in range(len(temp)):
    if temp[i]>0 or temp[i]<0:
        temp[i]=temp[i]*100

# Visualize the attribution for the attribution

from captum.attr import visualization as viz

indices = tokenized_sentence[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)
delta=torch.Tensor([0])
confidence=torch.max(fun_predict_captum(tokenized_sentence)[0])
label_pred=torch.argmax(fun_predict_captum(tokenized_sentence)[0])
ground_label=0
last_arg=0

attributions_start_sum = attr[0]

#  Change first 3 zero to 1 if positive class

start_position_vis = viz.VisualizationDataRecord(
                        temp,
                        confidence, 
                        label_pred,
                        ground_label,
                        last_arg,
                        temp.sum(),       
                        all_tokens,
                        delta)

print('\033[1m', 'Visualizations For Start Position', '\033[0m')
viz.visualize_text([start_position_vis])
# Out:
# Lime attribution:   0%|          | 0/10000 [00:00<?, ?it/s]
