# %%
from google.colab import drive
from pathlib import Path
import sys
# !pip install datasets transformers huggingface_hub
from datasets import load_dataset
from utils import data_structure

drive.mount('/content/drive/')
strPath = "drive/MyDrive/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models"
# sys.path.insert(0,"drive/MyDrive/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models")
filePath = Path(strPath)
# %cd $filePath
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.9/dist-packages (0.13.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models'
# /content/drive/MyDrive/Spurious_Correlations/Identifying-and-Mitigating-Spurious-Correlations-for-Improving-Robustness-in-NLP-Models

# %%
import pandas as pd

# %%
import pickle
import os
import numpy as np
import operator
dataset = "sst2"

# work_dir = "./naacl_2022"
# train_df = pd.read_csv(os.path.join(work_dir + "/transformers/glue_data/SST-2", "dev.tsv"), sep = '\t')

if dataset == "sst2":
  # train_df = pd.read_csv(os.path.join("transformers/glue_data/SST-2", "dev.tsv"), sep = '\t')
  train_df = data_structure.get_sst2()
  sentences = train_df["text"]
  labels = train_df["label"]
else:
  train_df = pd.read_csv(os.path.join("transformers/yelp_data/", "train.tsv"), sep = '\t')
  sentences = train_df["text"]
  labels = train_df["label"]
# Out:
# WARNING:datasets.builder:Found cached dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
df = data_structure.get_sst2()
print(df.text)
# Out:
# WARNING:datasets.builder:Found cached dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0             hide new secretions from the parental units
# 1                     contains no wit , only labored gags
# 2        that loves its characters and communicates som...
# 3        remains utterly satisfied to remain the same t...
# 4        on the worst revenge-of-the-nerds clichés the ...
#                                ...
# 67344                                 a delightful comedy
# 67345                     anguish , anger and frustration
# 67346    at achieving the modest , crowd-pleasing goals...
# 67347                                    a patient viewer
# 67348    this new jangle of noise , mayhem and stupidit...
# Name: text, Length: 67349, dtype: object

# %%
# load tokenizer and build vocab
from transformers import AutoTokenizer
# tokenizer = AutoTokenizer.from_pretrained("./models/SST_base_cased")

if dataset == "sst2":
  tokenizer = AutoTokenizer.from_pretrained("models/distilbert_SST_base_cased/") # make sure that the specified file has a config.json file in it
  vocab_filename = "models/distilbert_SST_base_cased/vocab.txt"
else:
  tokenizer = AutoTokenizer.from_pretrained("models/distilbert_yelp_base_uncased/") # make sure that the specified file has a config.json file in it
  vocab_filename = "models/distilbert_yelp_base_uncased/vocab.txt"

word2id = dict()
id2word = dict()
with open(vocab_filename, "r") as f:
    lines = f.readlines()
for idx, line in enumerate(lines):
    word2id[line.strip()] = idx
    id2word[idx] = line.strip()

# %%
print(word2id['[CLS]'])
print(tokenizer("I have a apple"))
# Out:
# 101
# {'input_ids': [101, 1045, 2031, 1037, 6207, 102], 'attention_mask': [1, 1, 1, 1, 1, 1]}

# %% [markdown]
# ### Test on SST test set

# %%
# Load attention weights and predictions
if dataset == "sst2":
  attention_sst_sst = np.load("models/distilbert_SST_base_cased/cls_attention_weights.npy")
  preds = np.load("models/distilbert_SST_base_cased/predictions.npy")
else:
  attention_sst_sst = np.load("models/distilbert_yelp_base_uncased/cls_attention_weights.npy")
  preds = np.load("models/distilbert_yelp_base_uncased/predictions.npy")

# %%
assert len(attention_sst_sst) == len(labels)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-71-aa9550971c17> in <cell line: 1>()
# ----> 1 assert len(attention_sst_sst) == len(labels)
#
# AssertionError:

# %%
print(sentences[0], labels[0])
# Out:
# hide new secretions from the parental units  0

# %%
preds_labels = []
for elem in preds:
    if elem[0] > elem[1]:
        preds_labels.append(0)
    else:
        preds_labels.append(1)

# %%
# compute acc
np.sum(np.equal(np.array(preds_labels), np.array(labels.tolist())))/len(preds_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-37642786f120> in <cell line: 2>()
#       1 # compute acc
# ----> 2 np.sum(np.equal(np.array(preds_labels), np.array(labels.tolist())))/len(preds_labels)
#
# ValueError: operands could not be broadcast together with shapes (872,) (67349,)

# %%
wrong_ids = []
correct_ids = []
for idx in range(len(preds_labels)):
    if preds_labels[idx] != labels[idx]:
#     if preds_labels[idx] == 0:
        wrong_ids.append(idx)
    else:
        correct_ids.append(idx)
print(len(wrong_ids))
print(len(correct_ids))
# Out:
# 78
# 794

# %% [markdown]
# ### Analysis on wrong predictions

# %%
def combine_tokens(tokens, scores=None):
    if scores is None:
        token_stack = []

        if len(tokens) > 128:
            sep = tokens[-1]
            tokens = tokens[:127]
            tokens.append(sep)

        for idx, token in enumerate(tokens):

            if len(token_stack) > 0 and token_stack[-1] == "'" and token == 't':
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token
            elif len(token_stack) > 0 and token == '##s' and token_stack[-1] == "her":
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token.replace("#", "")
            elif len(token_stack) > 0 and token == '.' and token_stack[-1] in ['mr', 'mrs', 'ms']:
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token
            elif len(token_stack) > 0 and token == '-':
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token
            elif len(token_stack) > 0 and token_stack[-1][-1] == '-':
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token
            elif len(token_stack) > 0 and "'" in token:
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token
            elif "#" in token:
                pre_token = token_stack[-1]
                new_token = pre_token + token
                token_stack[-1] = new_token.replace("#", "")
            else:
                token_stack.append(token)
                
        return token_stack

    token_stack = []
    score_stack = []
    
    if len(tokens) > 128:
        sep = tokens[-1]
        tokens = tokens[:127]
        tokens.append(sep)
        
    for idx, token in enumerate(tokens):
                
        if len(token_stack) > 0 and token_stack[-1] == "'" and token == 't':
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token
            score_stack[-1] = new_score
        elif len(token_stack) > 0 and token == '##s' and token_stack[-1] == "her":
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token.replace("#", "")
            score_stack[-1] = new_score
        elif len(token_stack) > 0 and token == '.' and token_stack[-1] in ['mr', 'mrs', 'ms']:
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token
            score_stack[-1] = new_score
        elif len(token_stack) > 0 and token == '-':
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token
            score_stack[-1] = new_score
        elif len(token_stack) > 0 and token_stack[-1][-1] == '-':
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token
            score_stack[-1] = new_score
        elif len(token_stack) > 0 and "'" in token:
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token
            score_stack[-1] = new_score
        elif "#" in token:
            pre_token = token_stack[-1]
            pre_score = score_stack[-1]
            new_token = pre_token + token
            new_score = pre_score + scores[idx]
            token_stack[-1] = new_token.replace("#", "")
            score_stack[-1] = new_score
        else:
            token_stack.append(token)
            score_stack.append(scores[idx])
    assert len(token_stack) == len(score_stack)
    return token_stack, score_stack

# %%
# Create a dict that contains the frequency of a token
frequency_dict = dict()
for idx in range(len(attention_sst_sst)):
    tokens = [id2word[item] for item in tokenizer(sentences[idx])["input_ids"]]
    tokens, scores = combine_tokens(tokens, attention_sst_sst[idx, :])
    for token in tokens:
        fre = frequency_dict.get(token, 0)
        frequency_dict[token] = fre + 1

# %%
# most important words for neg/pos prediction
atten_words = dict()

for idx in range(len(attention_sst_sst)):
    atten = attention_sst_sst[idx, :]
    logits = preds[idx]
    logits = np.exp(logits)/sum(np.exp(logits))
    tokens = [id2word[item] for item in tokenizer(sentences[idx])["input_ids"]]
    tokens, scores = combine_tokens(tokens, atten)
    
    if logits[1] > logits[0]:
        for score_idx, score in enumerate(scores):
            token = tokens[score_idx]
            if "[SEP]" in token or "[CLS]" in token:
                continue
            
            if not token in atten_words:
                atten_words[token] = []
            atten_words[token].append(score*logits[1])
    else:
        for score_idx, score in enumerate(scores):
            token = tokens[score_idx]
            if "[SEP]" in token or "[CLS]" in token:
                continue
            
            if not token in atten_words:
                atten_words[token] = []
            atten_words[token].append(-score*logits[0])

# %%
print(len(atten_words), len(frequency_dict))
print(atten_words['lacks'])
print(frequency_dict['lacks'] == len(atten_words['lacks']))
# Out:
# 2719 2729
# [0.01993039, -0.03193205]
# True

# %%
use_logistic_regression = True

if not use_logistic_regression:
  new_words = dict()
  for token in atten_words:
      if len(atten_words[token]) > 0:
          # average attention for a given token
          new_words[token] = abs(sum(atten_words[token]))/len(atten_words[token])
          
  normed_words = dict()
  words_sum = sum(new_words.values())
  for k in new_words:
      normed_words[k] = np.log(new_words[k]/words_sum) - 4/np.log(1+frequency_dict[k]) # change lambda, currently set as 4
  import operator
  sorted_words = sorted(normed_words.items(), key=operator.itemgetter(1), reverse=True)

  # Token, Importance score, Frequency, average attention score
  for item in sorted_words[:50]:
      print("{: <16}".format(item[0]), "\t%.6f"%(item[1]), "\t%5d"%(len(atten_words[item[0]])), 
          "\t%.6f"%(new_words[item[0]])) # "\t{}".format("\t".join([str(item) for item in atten_words[item[0]]])))

else:
  import csv
  important_toks = []
  normed_words = {}
  frequency_dict = {}
  original_score = {}
  new_words = {}
  words_sum = 0
  if dataset == "sst2":
    with open("../emnlp-2020-spurious/tokens/sst2_important_tokens.csv", mode='r') as file:
      csvFile = csv.reader(file)
      for lines in csvFile:
        important_toks.append(lines)
        words_sum += abs(float(lines[1]))
  elif dataset == "yelp":
    with open("../emnlp-2020-spurious/tokens/yelp_important_tokens.csv", mode='r') as file:
      csvFile = csv.reader(file)
      for lines in csvFile:
        important_toks.append(lines)
        words_sum += abs(float(lines[1]))

  # print(words_sum)
  for line in important_toks:
    curr_tok = line[0]
    curr_score = float(line[1] )
    curr_freq = int(line[2])

    new_words[curr_tok] = abs(curr_score)
    frequency_dict[curr_tok] = curr_freq
    normed_words[curr_tok] = np.log(abs(curr_score)/words_sum) - 4/np.log(1+curr_freq)
    original_score[curr_tok] = curr_score

  import operator
  sorted_words = sorted(normed_words.items(), key=operator.itemgetter(1), reverse=True)

  # Token, Importance score, Frequency, Original logistic regression score
  for item in sorted_words[:50]:
      print("{: <16}".format(item[0]), "\t%.6f"%(item[1]),"\t%5d"%(frequency_dict[item[0]]),"\t%.6f"%(original_score[item[0]])) # "\t{}".format("\t".join([str(item) for item in atten_words[item[0]]])))
# Out:
# worst            	-8.163862 	  270 	4.076367
# lacks            	-8.229741 	  134 	4.223908
# lacking          	-8.240253 	  106 	4.352772
# remarkable       	-8.333685 	  176 	-3.647869
# mess             	-8.362296 	  149 	3.636636
# powerful         	-8.383788 	  242 	-3.318314
# stupid           	-8.399924 	  142 	3.529367
# failure          	-8.423783 	   83 	3.796342
# beautiful        	-8.428619 	  251 	-3.157676
# fascinating      	-8.455213 	  304 	-3.001472
# wonderful        	-8.459947 	  174 	-3.220645
# hilarious        	-8.462791 	  192 	-3.165558
# bad              	-8.465366 	  886 	2.661729
# enjoyable        	-8.471997 	  266 	-3.001078
# devoid           	-8.502347 	   73 	3.604056
# none             	-8.514476 	  130 	3.193304
# lack             	-8.528424 	  166 	3.028858
# waste            	-8.534680 	  114 	3.200727
# refreshing       	-8.541350 	   77 	-3.427487
# charming         	-8.555369 	  232 	-2.810856
# terrific         	-8.562534 	  156 	-2.955358
# solid            	-8.571638 	  233 	-2.763903
# too              	-8.604006 	 1187 	2.261473
# pointless        	-8.605750 	   93 	3.094795
# poorly           	-8.611350 	  104 	3.013751
# depressing       	-8.611539 	   89 	3.103220
# appealing        	-8.614680 	  124 	-2.911941
# clichés          	-8.624564 	  122 	2.891318
# best             	-8.626035 	  827 	-2.280382
# bore             	-8.629980 	   62 	3.288810
# less             	-8.632377 	  383 	2.447024
# pretentious      	-8.632397 	  118 	2.885302
# neither          	-8.636057 	  104 	2.940203
# dull             	-8.638163 	  293 	2.510977
# unfunny          	-8.639626 	  112 	2.890878
# flat             	-8.654394 	  195 	2.607795
# poor             	-8.658845 	   90 	2.953400
# treat            	-8.678198 	   75 	-3.005625
# entertaining     	-8.686167 	  477 	-2.264207
# fails            	-8.686866 	  148 	2.631506
# ugly             	-8.687931 	  138 	2.658454
# engrossing       	-8.693985 	  120 	-2.705083
# heart            	-8.698184 	  478 	-2.236670
# unnecessary      	-8.698933 	   71 	2.978525
# touching         	-8.699575 	  178 	-2.525853
# no               	-8.704237 	 1034 	2.068876
# boring           	-8.706338 	  167 	2.532888
# brilliant        	-8.720454 	  139 	-2.570360
# intriguing       	-8.727218 	  167 	-2.480551
# hardly           	-8.728479 	   70 	2.900695

# %%
print(frequency_dict['is'])
# Out:
# 8115

# %%
if dataset == "sst2":
  token = 'downer'
else:
  token = "inattentive"
print(frequency_dict[token])
print(atten_words[token])

# you can have negative attention? Is this like the wang cutello paper where negative indicates bad sentiment and positive indicates good sentiment?
print(abs(sum(atten_words[token]))/len(atten_words[token]))
# Out:
# 9
# [-0.23070532, -0.20780681, -0.1133861]
# 0.18396607786417007

# %%
a = [item[0] for item in sorted_words[:50]]
print(", ".join(a))
# Out:
# worst, lacks, lacking, remarkable, mess, powerful, stupid, failure, beautiful, fascinating, wonderful, hilarious, bad, enjoyable, devoid, none, lack, waste, refreshing, charming, terrific, solid, too, pointless, poorly, depressing, appealing, clichés, best, bore, less, pretentious, neither, dull, unfunny, flat, poor, treat, entertaining, fails, ugly, engrossing, heart, unnecessary, touching, no, boring, brilliant, intriguing, hardly

# %% [markdown]
# ### Dump normalized frequency and attention scores

# %%
normed_freq = dict()
fre_sum = sum(list(frequency_dict.values())) # num unique tokens?
data = [elem for elem in list(frequency_dict.values())]
fre_mean = np.mean(data)
fre_max = np.max(data)
fre_std = np.std(data)

print("unique tokens, average frequency, freq std dev and freq max")
print(fre_sum, fre_mean, fre_std, fre_max)
for k in frequency_dict:
    normed_freq[k] = (frequency_dict[k]/fre_sum)# / fre_std
print("frequency of word \'lacks\' and normed frequency of word \'lacks\'")
print(frequency_dict['lacks'], normed_freq['lacks'])


if not use_logistic_regression:    
  new_words = dict()
  for token in atten_words:
      if len(atten_words[token]) > 0:
          new_words[token] = abs(sum(atten_words[token]))/len(atten_words[token])
 
normed_words = dict()
words_sum = sum(new_words.values())
data = [elem for elem in list(new_words.values())]
atten_max = np.max(data)
atten_mean = np.mean(data)
atten_std = np.std(data)
print("words sum, attention mean, attention std dev")
print(words_sum, atten_mean, atten_std)
for k in new_words:
    normed_words[k] = (new_words[k]/words_sum)# / atten_std

print(new_words.keys())
print("average attention for word \'lacks\' and normalized average attention for word \'lacks\'")
print(new_words['lacks'], normed_words['lacks'])
print("average attention for word \'complaints\' and normalized average attention for word \'complaints\'")
print(new_words['terrible'], normed_words['terrible'])
# Out:
# unique tokens, average frequency, freq std dev and freq max
# 527590 49.78673209398887 381.4068814422797 20041
# frequency of word 'lacks' and normed frequency of word 'lacks'
# 134 0.0002539851020678936
# words sum, attention mean, attention std dev
# 7009.719217154006 0.6614814775081633 0.5363650239263338
# dict_keys(['lacking', 'lacks', 'worst', 'failure', 'mess', 'devoid', 'stupid', 'bore', 'squanders', 'waste', 'none', 'depressing', 'pointless', 'nowhere', 'loses', 'lack', 'poorly', 'lousy', 'unnecessary', 'poor', 'neither', 'hardly', 'lackluster', 'listless', 'clichés', 'unfunny', 'pretentious', 'wannabe', 'useless', 'repetitive', 'distasteful', 'copy', 'tiresome', 'unfortunately', 'pretends', 'generic', 'lame', 'bad', 'ugly', 'fails', 'insulting', 'uninspired', 'flat', 'insult', 'unpleasant', 'irritating', 'uneven', 'charmless', 'amateurish', 'cliché', 'shame', 'boring', 'obnoxious', 'scarcely', 'worse', 'elsewhere', 'mistake', 'weak', 'dull', 'overbearing', 'muddled', 'unimaginative', 'disaster', 'superficial', 'overlong', 'annoying', 'crap', 'stale', 'shallow', 'foul', 'less', 'dreary', 'alabama', 'inept', 'bored', 'tedious', 'trash', 'cold', 'letdown', 'offensive', 'misses', 'embarrassment', 'bland', 'painful', 'nor', 'disappointment', 'tired', 'junk', 'contrived', 'sluggish', 'comparison', 'misery', 'hack', 'problem', 'dilutes', 'ill', 'sinks', 'too', 'shapeless', 'ridiculous', 'sleep', 'clumsy', 'wastes', 'pity', 'hole', 'mindless', 'badly', 'mediocre', 'soggy', 'hackneyed', 'wasted', 'failed', 'alienating', 'guess', 'awful', 'topless', 'empty', 'low', 'suffers', 'rerun', 'supposed', 'fool', 'hollow', 'forgets', 'endure', 'saddest', 'phony', 'predictable', 'excruciating', 'devolves', 'terrible', 'missing', 'depress', 'tepid', 'toilet', 'barely', 'crude', 'needs', 'unconvincing', 'absurd', 'violence', 'numbing', 'lost', 'artificial', 'false', 'winds', 'foolish', 'preposterous', 'fell', 'skip', 'marathons', 'irrelevant', 'unfocused', 'cheesy', 'stinker', 'no', 'chosen', 'smirk', 'stomps', 'bleak', 'uninvolving', 'garbage', 'putrid', 'falls', 'trite', 'kills', 'thin', 'facetious', 'hastily', 'attack', 'opposite', 'limitations', 'awkward', 'sag', 'detached', 'uneasy', 'fake', 'money', 'astray', 'indigestion', 'ludicrous', 'formulaic', 'soulless', 'squeezed', 'cliche', 'unfulfilling', 'horrible', 'thinks', 'dumb', 'disappointments', 'unlikable', 'misguided', 'worthless', 'manipulative', 'overwritten', 'vague', 'rent', 'lazier', 'fees', 'choppy', 'appalling', 'drag', 'harder', 'repugnant', 'cliched', 'abandon', 'dullest', 'rut', 'preachy', 'hideously', 'nightmare', 'vulgar', 'banal', 'sided', 'unless', 'monday', 'intolerable', 'denial', 'vapid', 'blind', 'cesspool', 'rating', 'holes', 'weary', 'whimper', 'confusing', 'lifeless', 'flatly', 'naive', 'dim', 'flimsy', 'overwrought', 'incoherent', 'impersonal', 'bogus', 'fragmented', 'assumes', 'glum', 'dumbness', 'problems', 'zero', 'disposable', 'wooden', 'not', 'static', 'sordid', 'clunky', 'similar', 'desired', 'torture', 'implausible', 'diminishing', 'stature', 'bottom', 'expects', 'grating', 'buying', 'witless', 'ick', 'overly', 'drags', 'were', 'sick', 'burnt', 'moronic', 'loathsome', 'gross', 'losers', 'strung', 'dry', 'inconsequential', 'cheapo', 'crappy', 'uninteresting', 'stiff', 'collapses', 'snore', 'joke', 'difficult', 'realizing', 'biased', 'turkey', 'cheapened', 'bile', 'backward', 'sloppy', 'corpse', 'forgettable', 'stopped', 'unappealing', 'supposedly', 'sadly', 'basketball', 'broiling', 'advice', 'excuse', 'taken', 'unendurable', 'heavy', 'disappointing', 'plodding', 'insipid', 'whiny', 'frantic', 'blandness', 'distanced', 'uncomfortable', 'tries', 'showgirls', 'abomination', 'thinly', 'absurdities', 'limited', 'chicken', 'cruel', 'confuses', 'appears', 'propaganda', 'fatal', 'interests', 'reeks', 'fluke', 'distant', 'dollars', 'pitifully', 'disservice', 'mediocrity', 'inevitable', 'unsympathetic', 'muddy', 'dreadful', 'insignificance', 'bleed', 'sucked', 'lameness', 'collinwood', 'chump', 'apartheid', 'tattered', 'disjointed', 'soap', 'thrown', 'misfire', 'feathers', 'distressing', 'crummy', 'behave', 'pollution', 'sappiness', 'broken', 'called', 'mean', 'limp', 'slip', 'fail', 'says', 'ugliness', 'lower', 'petri', 'wishing', 'degrades', 'cliches', 'reason', 's ...
# average attention for word 'lacks' and normalized average attention for word 'lacks'
# 4.223907826419257 0.000602578747531373
# average attention for word 'complaints' and normalized average attention for word 'complaints'
# 2.1389608846404866 0.0003051421630992117

# %%
import pickle

saved_words = {}

for k in normed_words:
    saved_words[k] = {'normed_atten': normed_words[k], 'normed_fre': normed_freq[k]}

if dataset == "sst2":
  path = "logistic_regression/glue_data/SST-2/"
  if not os.path.exists(path):
    os.makedirs(path)
  pickle.dump(saved_words, open(path + "saved_words.p", 'wb'))
else:
  path = "logistic_regression/yelp_data/"
  if not os.path.exists(path):
    os.makedirs(path)
  pickle.dump(saved_words, open(path + "saved_words.p", 'wb'))

# %% [markdown]
# ### Compare two lists

# %%
# words_sst = pickle.load(open("transformers/glue_data/SST-2/saved_words.p", "rb"))
# words_yelp = pickle.load(open("transformers/yelp_data/saved_words.p", "rb"))
words_sst = pickle.load(open("logistic_regression/glue_data/SST-2/saved_words.p", "rb"))
words_yelp = pickle.load(open("logistic_regression/yelp_data/saved_words.p", "rb"))

# %%
vocab_union = set(words_sst.keys()).union(set(words_yelp.keys()))
# print(len(set(words_sst.keys()).intersection(set(words_yelp.keys())))) # Intersection contains 2686 words, need to cross reference the paper tomorrow
print(len(vocab_union))
id2word_union = {}
word2id_union = {}
for idx, w in enumerate(vocab_union):
    id2word_union[idx] = w
    word2id_union[w] = idx
# Out:
# 22582

# %%
print(len(words_sst), len(words_yelp))
# Out:
# 10597 18183

# %%
# Original fre_sum
# total_fre_sst = 768543
# total_fre_yelp = 363504

# Our attention fre_sum
# total_fre_sst = 18849 
# total_fre_yelp = 753242 

# Our Logistic Regression fre_sum
total_fre_sst = 527590  
total_fre_yelp = 3032301

# %%
sst_all = dict()
yelp_all = dict()
for i in range(len(id2word)):
    w = id2word[i]
    if w in words_sst:
        tmp = np.log(words_sst[w]['normed_atten']) - 4/np.log(1+words_sst[w]['normed_fre'] * total_fre_sst)
        sst_all[w] = tmp
    
    if w in words_yelp:
        tmp = np.log(words_yelp[w]['normed_atten']) - 4/np.log(1+words_yelp[w]['normed_fre'] * total_fre_yelp)
        yelp_all[w] = tmp
        
sst_max, sst_min = max(sst_all.values()), min(sst_all.values())
yelp_max, yelp_min = max(yelp_all.values()), min(yelp_all.values())
max_sst_fre = max([words_sst[w]['normed_fre'] for w in words_sst])
max_yelp_fre = max([words_yelp[w]['normed_fre'] for w in words_yelp])
diff_all = dict()
for w in word2id:
    if w in words_sst:
        sst_v = (sst_all[w] - sst_min) / (sst_max - sst_min)
    
        if w in words_yelp:
            yelp_v = (yelp_all[w] - yelp_min) / (yelp_max - yelp_min)
        else:
            yelp_v = 0
        
        diff_all[w] = (sst_v - yelp_v)
        
# exclude "good"
sorted_words = sorted(diff_all.items(), key=operator.itemgetter(1), reverse=True)
sst_values = list(sst_all.values())
yelp_values = list(yelp_all.values())
sst_values.sort(reverse=True)
yelp_values.sort(reverse=True)

print("{: <16}\t{}\t{}\t{}\t{}\t{}\t{}\t{}".format("**word**", "diff", "s score", "y score", "s rank",
                                                  "s fre", "y rank", "y fre"))

atten_sum = 0
for item in sorted_words[:50]:
    w = item[0]
    idx = word2id[w]
    atten_sum += (sst_all[w] - sst_min) / (sst_max - sst_min)
    print("{: <16}\t{:2.4f}\t{:02.2f}\t{:2.2f}\t{:05}\t{:5.2f}\t{:05}\t{:5.2f}".format(w, diff_all[w],
                            (sst_all[w] - sst_min) / (sst_max - sst_min) if w in words_sst else 0, 
                            (yelp_all[w] - yelp_min) / (yelp_max - yelp_min) if w in words_yelp else 0,                                                     
                             sst_values.index(sst_all[w]) if w in words_sst else 0, 
                              (words_sst[w]['normed_fre'] if w in words_sst else 0) * total_fre_sst,
                              yelp_values.index(yelp_all[w]) if w in words_yelp else 0, 
                              (words_yelp[w]['normed_fre'] if w in words_yelp else 0)* total_fre_yelp
                             ))
#     print("{: <16}\t{:5.2f}".format(w,
#                               (words_sst[w]['normed_fre'] if w in words_sst else 0) * total_fre_sst))
print(atten_sum/50)
# Out:
# **word**        	diff	s score	y score	s rank	s fre	y rank	y fre
# provocative     	0.9446	0.94	0.00	00070	103.00	00000	 0.00
# compelling      	0.9444	0.94	0.00	00073	356.00	00000	 0.00
# superficial     	0.9428	0.94	0.00	00080	73.00	00000	 0.00
# captures        	0.9410	0.94	0.00	00088	91.00	00000	 0.00
# violence        	0.9389	0.94	0.00	00097	130.00	00000	 0.00
# dazzling        	0.9322	0.93	0.00	00133	65.00	00000	 0.00
# succeeds        	0.9313	0.93	0.00	00140	71.00	00000	 0.00
# clarity         	0.9287	0.93	0.00	00150	80.00	00000	 0.00
# affection       	0.9210	0.92	0.00	00191	86.00	00000	 0.00
# sensual         	0.9162	0.92	0.00	00230	48.00	00000	 0.00
# vivid           	0.9148	0.91	0.00	00245	83.00	00000	 0.00
# embracing       	0.9085	0.91	0.00	00293	20.00	00000	 0.00
# fatal           	0.9084	0.91	0.00	00295	60.00	00000	 0.00
# anatomical      	0.9070	0.91	0.00	00308	17.00	00000	 0.00
# prose           	0.9055	0.91	0.00	00322	14.00	00000	 0.00
# wry             	0.9028	0.90	0.00	00347	47.00	00000	 0.00
# sitcom          	0.9024	0.90	0.00	00355	59.00	00000	 0.00
# reveals         	0.9020	0.90	0.00	00358	65.00	00000	 0.00
# spielberg       	0.9020	0.90	0.00	00359	93.00	00000	 0.00
# scarcely        	0.9003	0.90	0.00	00381	14.00	00000	 0.00
# meaningful      	0.8997	0.90	0.00	00388	43.00	00000	 0.00
# bleak           	0.8996	0.90	0.00	00393	22.00	00000	 0.00
# explores        	0.8995	0.90	0.00	00396	19.00	00000	 0.00
# dickens         	0.8961	0.90	0.00	00432	28.00	00000	 0.00
# absorbing       	0.8948	0.89	0.00	00450	66.00	00000	 0.00
# startling       	0.8945	0.89	0.00	00454	40.00	00000	 0.00
# exploitation    	0.8945	0.89	0.00	00456	49.00	00000	 0.00
# flawed          	0.8943	0.89	0.00	00458	71.00	00000	 0.00
# detached        	0.8937	0.89	0.00	00465	19.00	00000	 0.00
# collapses       	0.8934	0.89	0.00	00469	27.00	00000	 0.00
# comedies        	0.8926	0.89	0.00	00476	133.00	00000	 0.00
# uniquely        	0.8914	0.89	0.00	00494	18.00	00000	 0.00
# achievement     	0.8904	0.89	0.00	00504	63.00	00000	 0.00
# haunting        	0.8900	0.89	0.00	00512	57.00	00000	 0.00
# irresistible    	0.8899	0.89	0.00	00513	37.00	00000	 0.00
# triumph         	0.8891	0.89	0.00	00521	70.00	00000	 0.00
# distinguished   	0.8885	0.89	0.00	00535	31.00	00000	 0.00
# chord           	0.8862	0.89	0.00	00560	23.00	00000	 0.00
# bracing         	0.8854	0.89	0.00	00568	25.00	00000	 0.00
# forceful        	0.8837	0.88	0.00	00585	20.00	00000	 0.00
# poetic          	0.8829	0.88	0.00	00604	64.00	00000	 0.00
# radical         	0.8827	0.88	0.00	00609	27.00	00000	 0.00
# gripping        	0.8825	0.88	0.00	00611	74.00	00000	 0.00
# bourne          	0.8817	0.88	0.00	00630	30.00	00000	 0.00
# transforms      	0.8812	0.88	0.00	00637	21.00	00000	 0.00
# ponder          	0.8803	0.88	0.00	00646	29.00	11337	 5.00
# sweetly         	0.8800	0.88	0.00	00650	42.00	00000	 0.00
# deaths          	0.8792	0.88	0.00	00661	21.00	00000	 0.00
# earnest         	0.8782	0.88	0.00	00684	100.00	00000	 0.00
# whimper         	0.8771	0.88	0.00	00707	14.00	00000	 0.00
# 0.9009657522936131

# %%
print([item[0] for item in sorted_words[:300]])
# Out:
# ['provocative', 'compelling', 'superficial', 'captures', 'violence', 'dazzling', 'succeeds', 'clarity', 'affection', 'sensual', 'vivid', 'embracing', 'fatal', 'anatomical', 'prose', 'wry', 'sitcom', 'reveals', 'spielberg', 'scarcely', 'meaningful', 'bleak', 'explores', 'dickens', 'absorbing', 'startling', 'exploitation', 'flawed', 'detached', 'collapses', 'comedies', 'uniquely', 'achievement', 'haunting', 'irresistible', 'triumph', 'distinguished', 'chord', 'bracing', 'forceful', 'poetic', 'radical', 'gripping', 'bourne', 'transforms', 'ponder', 'sweetly', 'deaths', 'earnest', 'whimper', 'stereotypes', 'friendship', 'dynamics', 'breakthrough', 'flatly', 'subtly', 'bile', 'warriors', 'stunt', 'expressive', 'invasion', 'fragmented', 'poem', 'assumes', 'imagery', 'bard', 'pollution', 'uncertain', 'mysteries', 'hypnotic', 'illuminating', 'credible', 'propaganda', 'thriller', 'historically', 'sly', 'richly', 'argentine', 'adaptation', 'contradictory', 'emptiness', 'experimental', 'lawrence', 'yarn', 'crippled', 'inspirational', 'plots', 'penetrating', 'valiant', 'fearless', 'comedic', 'stylistic', 'undone', 'intellectual', 'improvised', 'awareness', 'seeks', 'pathology', 'villain', 'evans', 'bravery', 'strained', 'landscapes', 'stuart', 'sequel', 'cynical', 'jerking', 'devastating', 'arresting', 'continuity', 'shocks', 'conviction', 'storytelling', 'humming', 'corpse', 'stylized', 'procedural', 'secretary', 'endurance', 'youthful', 'embraced', 'curves', 'celebrates', 'metropolis', 'plotting', 'viewers', 'lyrical', 'eyre', 'primitive', 'disabilities', 'sway', 'skies', 'thematic', 'empowerment', 'eyelids', 'dimensional', 'settles', 'stature', 'infectious', 'cinematic', 'brooding', 'insights', 'equilibrium', 'exaggerated', 'unpredictable', 'psychotic', 'backward', 'fisted', 'capturing', 'fascination', 'portrayal', 'nash', 'fisher', 'pleas', 'jolt', 'tissues', 'welsh', 'effortlessly', 'chuckles', 'horrors', 'conclusions', 'crimes', 'hewitt', 'exploit', 'loneliness', 'directorial', 'repetition', 'graceful', 'establishes', 'aids', 'cerebral', 'anguish', 'prejudice', 'abyss', 'filmmaker', 'transparent', 'twisting', 'ambiguous', 'strains', 'survival', 'reckless', 'antonia', 'craven', 'hitler', 'hartley', 'spontaneous', 'intellect', 'submarine', 'breadth', 'iranian', 'heightened', 'fellowship', 'biography', 'miraculous', 'terrorists', 'acute', 'acclaim', 'politically', 'mystical', 'kwan', 'seductive', 'conflicts', 'italics', 'plotted', 'tremble', 'weep', 'protagonist', 'innovations', 'collapse', 'relentless', 'predecessor', 'substantive', 'knockout', 'flung', 'revenge', 'weaponry', 'searing', 'analytical', 'textbook', 'ballot', 'subordinate', 'fantasies', 'pulse', 'roberts', 'brutally', 'clenching', 'triangle', 'achievements', 'motionless', 'crossover', 'apparatus', 'effectiveness', '146', 'blair', 'victims', 'sustained', 'fingered', 'apocalypse', 'innocence', 'reinforcement', 'sheridan', 'seas', 'composition', 'flashes', 'victories', 'schneider', 'discreet', 'imperfect', 'friendships', 'feminist', 'sonny', 'bullock', 'grips', '91', 'poverty', 'troubled', 'fontaine', 'eastwood', 'walsh', 'marred', 'exposition', 'proposal', 'crushing', 'restoring', 'fertile', 'resentment', 'demonstrate', 'literary', 'esther', 'courageous', 'vulnerable', 'devastation', 'creeping', 'significance', 'reconstruction', 'psyche', 'paranoia', 'undo', 'reduces', 'blooded', 'barlow', 'shrill', 'darkly', 'gore', 'alternately', 'cardiac', 'cultivation', 'careers', 'conspiracy', 'attracting', 'employs', 'engages', 'extremes', 'manipulation', 'testimony', 'momentum', 'swan', 'chamber', 'harvard', 'dubbed']

# %%
potential_shortcuts = [item[0] for item in sorted_words[:300]]
shortcuts2cnt = dict()

# Go through each sentence of the dataset, extract tokens
for idx in range(len(preds_labels)):
    sen = sentences[idx]
    tokens = [id2word[item] for item in tokenizer(sen)["input_ids"]] # is the number of tokens the same as the number of words in the sentence
    tokens = combine_tokens(tokens)
    for w in potential_shortcuts:
        if w in tokens:
            if w not in shortcuts2cnt:
                shortcuts2cnt[w] = []
            tmp = shortcuts2cnt[w]
            tmp.append(idx)
            shortcuts2cnt[w] = tmp
for w in shortcuts2cnt:
    print(w, len(shortcuts2cnt[w]))
# Out:
# superficial 1
# succeeds 2
# feminist 2
# conspiracy 2
# horrors 1
# vivid 3
# emptiness 1
# relentless 1
# eastwood 1
# earnest 4
# historically 1
# extremes 1
# cinematic 3
# storytelling 1
# tissues 1
# bourne 1
# conviction 4
# collapse 1
# portrayal 2
# reveals 2
# adaptation 2
# sequel 2
# compelling 4
# unpredictable 2
# conclusions 1
# ponder 1
# flashes 1
# subordinate 2
# crossover 1
# blair 2
# esther 1
# grips 1
# viewers 2
# haunting 3
# momentum 1
# filmmaker 1
# backward 2
# argentine 1
# celebrates 1
# vulnerable 1
# violence 2
# thriller 4
# seeks 1
# thematic 2
# captures 1
# submarine 1
# sitcom 1
# wry 1
# plots 1
# plotted 1
# predecessor 2
# comedies 3
# meaningful 1
# literary 1
# bard 1
# bleak 1
# poem 1
# affection 1
# pathology 1
# embracing 1
# intellectual 1
# stereotypes 1
# comedic 1
# restoring 1
# detached 1
# exaggerated 1
# yarn 1
# innocence 1
# kwan 1
# spielberg 1
# stylistic 1

# %%
import random

for w in shortcuts2cnt:
    print(w)
    tmp = shortcuts2cnt[w]
    random.shuffle(tmp)
    for idx in tmp[:5]:
        print(sentences[idx])
    print("")
# Out:
# bleak
# unflinchingly bleak and desperate
#
# filmmaker
# not since japanese filmmaker akira kurosawa 's ran have the savagery of combat and the specter of death been visualized with such operatic grandeur .
# ramsay , as in ratcatcher , remains a filmmaker with an acid viewpoint and a real gift for teasing chilly poetry out of lives and settings that might otherwise seem drab and sordid .
# displaying about equal amounts of naiveté , passion and talent , beneath clouds establishes sen as a filmmaker of considerable potential .
# allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker .
#
# violence
# this re-do is so dumb and so exploitative in its violence that , ironically , it becomes everything that the rather clumsy original was railing against .
# ... mafia , rap stars and hood rats butt their ugly heads in a regurgitation of cinematic violence that gives brutal birth to an unlikely , but likable , hero . '
# excessive , profane , packed with cartoonish violence and comic-strip characters .
# ... the film suffers from a lack of humor ( something needed to balance out the violence ) ...
# does n't offer much besides glib soullessness , raunchy language and a series of brutal set pieces ... that raise the bar on stylized screen violence .
#
# thriller
# ... an otherwise intense , twist-and-turn thriller that certainly should n't hurt talented young gaghan 's resume .
# ... plays like somebody spliced random moments of a chris rock routine into what is otherwise a cliche-riddled but self-serious spy thriller .
# a taut psychological thriller that does n't waste a moment of its two-hour running time .
# professionally speaking , it 's tempting to jump ship in january to avoid ridiculous schlock like this shoddy suspense thriller .
# a lean , deftly shot , well-acted , weirdly retro thriller that recalls a raft of '60s and '70s european-set spy pictures .
#
# uncertain
# nicks , seemingly uncertain what 's going to make people laugh , runs the gamut from stale parody to raunchy sex gags to formula romantic comedy .
#
# significance
# it 's an offbeat treat that pokes fun at the democratic exercise while also examining its significance for those who take part .
#
# compelling
# it provides the grand , intelligent entertainment of a superior cast playing smart people amid a compelling plot .
# moretti 's compelling anatomy of grief and the difficult process of adapting to loss .
# thanks to scott 's charismatic roger and eisenberg 's sweet nephew , roger dodger is one of the most compelling variations on in the company of men .
# a poignant and compelling story about relationships , food of love takes us on a bumpy but satisfying journey of the heart .
# a compelling spanish film about the withering effects of jealousy in the life of a young monarch whose sexual passion for her husband becomes an obsession .
#
# seductive
# featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results .
# a gorgeous , witty , seductive movie .
# whether writer-director anne fontaine 's film is a ghost story , an account of a nervous breakdown , a trip down memory lane , all three or none of the above , it is as seductive as it is haunting .
#
# succeeds
# if the movie succeeds in instilling a wary sense of ` there but for the grace of god , ' it is far too self-conscious to draw you deeply into its world .
# while the resident evil games may have set new standards for thrills , suspense , and gore for video games , the movie really only succeeds in the third of these .
#
# fascination
# the weight of the piece , the unerring professionalism of the chilly production , and the fascination embedded in the lurid topic prove recommendation enough .
#
# illuminating
# this illuminating documentary transcends our preconceived vision of the holy land and its inhabitants , revealing the human complexities beneath .
#
# effortlessly
# holm ... embodies the character with an effortlessly regal charisma .
#
# intellectual
# it offers little beyond the momentary joys of pretty and weightless intellectual entertainment .
# a pleasant enough romance with intellectual underpinnings , the kind of movie that entertains even as it turns maddeningly predictable .
#
# emptiness
# a synthesis of cliches and absurdities that seems positively decadent in its cinematic flash and emptiness .
#
# cinematic
# a cartoon that 's truly cinematic in scope , and a story that 's compelling and heartfelt -- even if the heart belongs to a big , four-legged herbivore .
# ... mafia , rap stars and hood rats butt their ugly heads in a regurgitation of cinematic violence that gives brutal birth to an unlikely , but likable , hero . '
# fun , flip and terribly hip bit of cinematic entertainment .
# an intriguing cinematic omnibus and round-robin that occasionally is more interesting in concept than in execution .
# ... a hollow joke told by a cinematic gymnast having too much fun embellishing the misanthropic tale to actually engage it .
#
# eastwood
# has a lot of the virtues of eastwood at his best .
#
# primitive
# the primitive force of this film seems to bubble up from the vast collective memory of the combatants .
#
# chamber
# exquisitely nuanced in mood tics and dialogue , this chamber drama is superbly acted by the deeply appealing veteran bouquet and the chilling but quite human berling .
# chabrol has taken promising material for a black comedy and turned it instead into a somber chamber drama .
#
# blair
# one of creepiest , scariest movies to come along in a long , long time , easily rivaling blair witch or the others .
#
# triumph
# the son 's room is a triumph of gentility that earns its moments of pathos .
#
# submarine
# there is nothing outstanding about this film , but it is good enough and will likely be appreciated most by sailors and folks who know their way around a submarine .
#
# flashes
# this is a train wreck of an action film -- a stupefying attempt by the filmmakers to force-feed james bond into the mindless xxx mold and throw 40 years of cinematic history down the toilet in favor of bright flashes and loud bangs .
#
# viewers
# late marriage 's stiffness is unlikely to demonstrate the emotional clout to sweep u.s. viewers off their feet .
# it will grip even viewers who are n't interested in rap , as it cuts to the heart of american society in an unnerving way .
# hardly a masterpiece , but it introduces viewers to a good charitable enterprise and some interesting real people .
# at least one scene is so disgusting that viewers may be hard pressed to retain their lunch .
#
# reveals
# as a rumor of angels reveals itself to be a sudsy tub of supernatural hokum , not even ms. redgrave 's noblest efforts can redeem it from hopeless sentimentality .
# byler reveals his characters in a way that intrigues and even fascinates us , and he never reduces the situation to simple melodrama .
#
# reduces
# byler reveals his characters in a way that intrigues and even fascinates us , and he never reduces the situation to simple melodrama .
#
# prejudice
# this riveting world war ii moral suspense story deals with the shadow side of american culture : racial prejudice in its ugly and diverse forms .
#
# gripping
# a gripping movie , played with performances that are all understated and touching .
# an exhilarating futuristic thriller-noir , minority report twists the best of technology around a gripping story , delivering a riveting , pulse intensifying escapist adventure of the first order
# an operatic , sprawling picture that 's entertainingly acted , magnificently shot and gripping enough to sustain most of its 170-minute length .
# while undisputed is n't exactly a high , it is a gripping , tidy little movie that takes mr. hill higher than he 's been in a while .
#
# explores
# warm water under a red bridge is a quirky and poignant japanese film that explores the fascinating connections between women , water , nature , and sexuality .
# brilliantly explores the conflict between following one 's heart and following the demands of tradition .
# trademark american triteness and simplicity are tossed out the window with the intelligent french drama that deftly explores the difficult relationship between a father and son .
#
# lawrence
# ( lawrence bounces ) all over the stage , dancing , running , sweating , mopping his face and generally displaying the wacky talent that brought him fame in the first place .
#
# insights
# in the end , we are left with something like two ships passing in the night rather than any insights into gay love , chinese society or the price one pays for being dishonest .
#
# friendship
# a tender , witty , captivating film about friendship , love , memory , trust and loyalty .
# the volatile dynamics of female friendship is the subject of this unhurried , low-key film that is so off-hollywood that it seems positively french in its rhythms and resonance .
# a warm but realistic meditation on friendship , family and affection .
# uses sharp humor and insight into human nature to examine class conflict , adolescent yearning , the roots of friendship and sexual identity .
# the story and the friendship proceeds in such a way that you 're watching a soap opera rather than a chronicle of the ups and downs that accompany lifelong friendships .
#
# dynamics
# the volatile dynamics of female friendship is the subject of this unhurried , low-key film that is so off-hollywood that it seems positively french in its rhythms and resonance .
#
# absorbing
# a difficult , absorbing film that manages to convey more substance despite its repetitions and inconsistencies than do most films than are far more pointed and clear .
# reggio 's continual visual barrage is absorbing as well as thought-provoking .
#
# employs
# the jabs it employs are short , carefully placed and dead-center .
# characters still need to function according to some set of believable and comprehensible impulses , no matter how many drugs they do or how much artistic license avary employs .
#
# sequel
# a sequel that 's much too big for its britches .
# the continued good chemistry between carmen and juni is what keeps this slightly disappointing sequel going , with enough amusing banter -- blessedly curse-free -- to keep both kids and parents entertained .
# a lackluster , unessential sequel to the classic disney adaptation of j.m. barrie 's peter pan .
# it seems like i have been waiting my whole life for this movie and now i ca n't wait for the sequel .
#
# stylized
# does n't offer much besides glib soullessness , raunchy language and a series of brutal set pieces ... that raise the bar on stylized screen violence .
#
# engages
# the movie is beautiful to behold and engages one in a sense of epic struggle -- inner and outer -- that 's all too rare in hollywood 's hastier productions .
#
# provocative
# smart , provocative and blisteringly funny .
#
# revenge
# ahhhh ... revenge is sweet !
# a swashbuckling tale of love , betrayal , revenge and above all , faith .
# the best revenge may just be living well because this film , unlike other dumas adaptations , is far more likened to a treasure than a lengthy jail sentence .
#
# breadth
# the movie understands like few others how the depth and breadth of emotional intimacy give the physical act all of its meaning and most of its pleasure .
#
# earnest
# a grimly competent and stolid and earnest military courtroom drama .
# the socio-histo-political treatise is told in earnest strides ... ( and ) personal illusion is deconstructed with poignancy .
# oscar wilde 's masterpiece , the importance of being earnest , may be the best play of the 19th century .
#
# vivid
# the vivid lead performances sustain interest and empathy , but the journey is far more interesting than the final destination .
# martin and barbara are complex characters -- sometimes tender , sometimes angry -- and the delicate performances by sven wollter and viveka seldahl make their hopes and frustrations vivid .
#
# harvard
# stealing harvard aspires to comedic grand larceny but stands convicted of nothing more than petty theft of your time .
# stealing harvard is evidence that the farrelly bros. -- peter and bobby -- and their brand of screen comedy are wheezing to an end , along with green 's half-hearted movie career .
#
# iranian
# a rarity among recent iranian films : it 's a comedy full of gentle humor that chides the absurdity of its protagonist 's plight .
#
# endurance
# with virtually no interesting elements for an audience to focus on , chelsea walls is a triple-espresso endurance challenge .
#
# bourne
# ... with `` the bourne identity '' we return to the more traditional action genre .
#
# adaptation
# suffocated by its fussy script and uptight characters , this musty adaptation is all the more annoying since it 's been packaged and sold back to us by hollywood .
# it 's so good that its relentless , polished wit can withstand not only inept school productions , but even oliver parker 's movie adaptation .
# a lackluster , unessential sequel to the classic disney adaptation of j.m. barrie 's peter pan .
# sticky sweet sentimentality , clumsy plotting and a rosily myopic view of life in the wwii-era mississippi delta undermine this adaptation .
#
# relentless
# it 's so good that its relentless , polished wit can withstand not only inept school productions , but even oliver parker 's movie adaptation .
#
# friendships
# the story and the friendship proceeds in such a way that you 're watching a soap opera rather than a chronicle of the ups and downs that accompany lifelong friendships .
#
# conviction
# macdowell , whose wifty southern charm has anchored lighter affairs ... brings an absolutely riveting conviction to her role .
#
# predecessor
# the second coming of harry potter is a film far superior to its predecessor .
#
# meaningful
# a deep and meaningful film .
#
# brooding
# it proves quite compelling as an intense , brooding character study .
#
# comedies
# if you enjoy more thoughtful comedies with interesting conflicted characters ; this one is for you .
# it has charm to spare , and unlike many romantic comedies , it does not alienate either gender in the audience .
# ( a ) n utterly charming and hilarious film that reminded me of the best of the disney comedies from the 60s .
#
# comedic
# stealing harvard aspires to comedic grand larceny but stands convicted of nothing more than petty theft of your time .
#
# establishes
# displaying about equal amounts of naiveté , passion and talent , beneath clouds establishes sen as a filmmaker of considerable potential .
#
# fingered
# not since freddy got fingered has a major release been so painful to sit through .
#
# affection
# a warm but realistic meditation on friendship , family and affection .
#
# strains
# well-nigh unendurable ... though the picture strains to become cinematic poetry , it remains depressingly prosaic and dull .
# at times , the suspense is palpable , but by the end there 's a sense that the crux of the mystery hinges on a technicality that strains credulity and leaves the viewer haunted by the waste of potential .
#
# gore
# almost gags on its own gore .
# while the resident evil games may have set new standards for thrills , suspense , and gore for video games , the movie really only succeeds in the third of these .
#
# subtly
# building slowly and subtly , the film , sporting a breezy spontaneity and realistically drawn characterizations , develops into a significant character study that is both moving and wise .
# the film is beautifully mounted , but , more to the point , the issues are subtly presented , managing to walk a fine line with regard to the question of joan 's madness .
# it 's a remarkably solid and subtly satirical tour de force .
#
# wry
# while the ideas about techno-saturation are far from novel , they 're presented with a wry dark humor .
# director andrew niccol ... demonstrates a wry understanding of the quirks of fame .
#
# haunting
# maud and roland 's search for an unknowable past makes for a haunting literary detective story , but labute pulls off a neater trick in possession : he makes language sexy .
# whether writer-director anne fontaine 's film is a ghost story , an account of a nervous breakdown , a trip down memory lane , all three or none of the above , it is as seductive as it is haunting .
# a moody , multi-dimensional love story and sci-fi mystery , solaris is a thought-provoking , haunting film that allows the seeds of the imagination to germinate .
#
# startling
# it 's worth seeing just on the basis of the wisdom , and at times , the startling optimism , of the children .
#
# literary
# maud and roland 's search for an unknowable past makes for a haunting literary detective story , but labute pulls off a neater trick in possession : he makes language sexy .
# very psychoanalytical -- provocatively so -- and also refreshingly literary .
#
# exploit
# there are simply too many ideas floating around -- part farce , part sliding doors , part pop video -- and yet failing to exploit them .
#
# sitcom
# charles ' entertaining film chronicles seinfeld 's return to stand-up comedy after the wrap of his legendary sitcom , alongside wannabe comic adams ' attempts to get his shot at the big time .
# offers very little genuine romance and even fewer laughs ... a sad sitcom of a movie , largely devoid of charm .
# a breezy romantic comedy that has the punch of a good sitcom , while offering exceptionally well-detailed characters .
# the director knows how to apply textural gloss , but his portrait of sex-as-war is strictly sitcom .
#
# pulse
# gives you the steady pulse of life in a beautiful city viewed through the eyes of a character who , in spite of tragic loss and increasing decrepitude , knows in his bones that he is one of the luckiest men alive .
# an exhilarating futuristic thriller-noir , minority report twists the best of technology around a gripping story , delivering a riveting , pulse intensifying escapist adventure of the first order
# there 's no emotional pulse to solaris .
#
# infectious
# an infectious cultural fable with a tasty balance of family drama and frenetic comedy .
# the movie has an infectious exuberance that will engage anyone with a passing interest in the skate/surf culture , the l.a. beach scene and the imaginative ( and sometimes illegal ) ways kids can make a playground out of the refuse of adults .
#
# fantasies
# generally , clockstoppers will fulfill your wildest fantasies about being a different kind of time traveler , while happily killing 94 minutes .
#
# plotting
# as ` chick flicks ' go , this one is pretty miserable , resorting to string-pulling rather than legitimate character development and intelligent plotting .
# sticky sweet sentimentality , clumsy plotting and a rosily myopic view of life in the wwii-era mississippi delta undermine this adaptation .
#
# awareness
# it inspires a continuing and deeply satisfying awareness of the best movies as monumental ` picture shows . '
#
# chuckles
# shaky close-ups of turkey-on-rolls , stubbly chins , liver spots , red noses and the filmmakers new bobbed do draw easy chuckles but lead nowhere .
#
# inspirational
# the inspirational screenplay by mike rich covers a lot of ground , perhaps too much , but ties things together , neatly , by the end .
#
# plotted
# adults will wish the movie were less simplistic , obvious , clumsily plotted and shallowly characterized .
#
# stylistic
# thanks to haynes ' absolute control of the film 's mood , and buoyed by three terrific performances , far from heaven actually pulls off this stylistic juggling act .
#
# lyrical
# it 's a stunning lyrical work of considerable force and truth .
#
# dazzling
# dazzling in its complexity , disturbing for its extraordinary themes , the piano teacher is a film that defies categorisation .
#
# captures
# care deftly captures the wonder and menace of growing up , but he never really embraces the joy of fuhrman 's destructive escapism or the grace-in-rebellion found by his characters .
#
# bard
# a disappointment for those who love alternate versions of the bard , particularly ones that involve deep fryers and hamburgers .
#
# flawed
# on the heels of the ring comes a similarly morose and humorless horror movie that , although flawed , is to be commended for its straight-ahead approach to creepiness .
#
# jerking
# the plot convolutions ultimately add up to nothing more than jerking the audience 's chain .
#
# storytelling
# sometimes seems less like storytelling than something the otherwise compelling director needed to get off his chest .
# first-time writer-director serry shows a remarkable gift for storytelling with this moving , effective little film .
#
# collapses
# in the end , the movie collapses on its shaky foundation despite the best efforts of director joe carnahan .
#
# cerebral
# too restrained to be a freak show , too mercenary and obvious to be cerebral , too dull and pretentious to be engaging ... the isle defies an easy categorization .
#
# curves
# the man from elysian fields is a cold , bliss-less work that groans along thinking itself some important comment on how life throws us some beguiling curves .
#
# stereotypes
# american chai encourages rueful laughter at stereotypes only an indian-american would recognize .
# my big fat greek wedding uses stereotypes in a delightful blend of sweet romance and lovingly dished out humor .
#
# brutally
# nelson 's brutally unsentimental approach ... sucks the humanity from the film , leaving behind an horrific but weirdly unemotional spectacle .
#
# spielberg
# there 's something auspicious , and daring , too , about the artistic instinct that pushes a majority-oriented director like steven spielberg to follow a.i. with this challenging report so liable to unnerve the majority .
#
# stuart
# very special effects , brilliantly bold colors and heightened reality ca n't hide the giant achilles ' heel in `` stuart little 2 `` : there 's just no story , folks .
#
# heightened
# very special effects , brilliantly bold colors and heightened reality ca n't hide the giant achilles ' heel in `` stuart little 2 `` : there 's just no story , folks .
#
# fatal
# the film makes a fatal mistake : it asks us to care about a young man whose only apparent virtue is that he is not quite as unpleasant as some of the people in his life .
#
# imagery
# exciting and direct , with ghost imagery that shows just enough to keep us on our toes .
#
# demonstrate
# late marriage 's stiffness is unlikely to demonstrate the emotional clout to sweep u.s. viewers off their feet .
#
# innocence
# visually imaginative , thematically instructive and thoroughly delightful , it takes us on a roller-coaster ride from innocence to experience without even a hint of that typical kiddie-flick sentimentality .

# %%
# I think there is supposed to be 8500 shortcuts, but we are now only getting 3
shortcut_sentences = set()
for k in shortcuts2cnt:
    for s_id in shortcuts2cnt[k]:
        shortcut_sentences.add(s_id)
print(len(shortcut_sentences))
shortcut_sentences = list(shortcut_sentences)
# Out:
# 381

# %% [markdown]
# ## Step 3

# %%
syns = pickle.load(open( "sst_syns.p", "rb" )) # load synonyms

generated_sens = dict()
generated_labels = dict()

for w in shortcuts2cnt:
    tmp = []
    
    if w in syns:
        replace_words = syns[w]
    else:
        replace_words = syns[w.lower()]
    
    for sen in shortcuts2cnt[w]:
        generated_labels[w] = labels[sen]
        sen = sentences[sen]
        
        if " "+w+" " in sen:
            for t in replace_words:
                tmp.append(sen.replace(" "+w+" ", " "+t+" "))
        elif w+" " in sen:
            for t in replace_words:
                tmp.append(sen.replace(w+" ", t+" "))
        elif " "+w in sen:
            for t in replace_words:
                tmp.append(sen.replace(" "+w, " "+t))
        elif w in sen:
            for t in replace_words:
                tmp.append(sen.replace(w, t))
        else:
            print("error")
            print(w, sen)
    generated_sens[w] = tmp

# %%
generated_sens_list = []
generated_labels_list = []
for k in generated_sens.keys():
    generated_sens_list += generated_sens[k]
    generated_labels_list += [generated_labels[k]] * len(generated_sens[k])
print(len(generated_sens_list))
print(len(generated_labels_list))

import csv

with open('./perturb/dev.tsv', 'wt') as out_file:
    tsv_writer = csv.writer(out_file, delimiter='\t')
    tsv_writer.writerow(['sentence', "label"])
    for idx, sentence in enumerate(generated_sens_list):
        tsv_writer.writerow([sentence.strip().replace("\n", " "), generated_labels_list[idx]])
    print(idx)
# Out:
# 93405
# 93405
# 93404

# %%
# eval the generated sentences using the trained model

# %%
ori_acc = dict()
for k in generated_sens.keys():
    ids = shortcuts2cnt[k]
    acc = np.sum(np.equal(np.array(preds_labels)[ids], np.array(labels)[ids]))/len(ids)
    ori_acc[k] = acc
print(ori_acc)

generated_preds = np.load("./perturb/predictions.npy")

generated_acc = dict()
pre_idx = 0
for k in generated_sens.keys():
    tmp_len = len(generated_sens[k])
    cur_labels = generated_labels_list[pre_idx:pre_idx+tmp_len]
    cur_preds = generated_preds[pre_idx:pre_idx+tmp_len]
    cur_preds_labels = []
    for elem in cur_preds:
        if elem[0] > elem[1]:
            cur_preds_labels.append(0)
        else:
            cur_preds_labels.append(1)
#     print(tmp_len, len(labels), len(preds_labels), len(preds))
    acc = np.sum(np.equal(np.array(cur_preds_labels), np.array(cur_labels)))/len(cur_preds_labels)
    generated_acc[k] = acc
    pre_idx += tmp_len
print(generated_acc)
# Out:
# {'superficial': 1.0, 'depressed': 1.0, 'redundant': 1.0, 'succeeds': 1.0, 'crude': 1.0, 'oblivious': 1.0, 'sharply': 1.0, 'recycled': 1.0, 'proves': 0.9858156028368794, 'vivid': 1.0, 'pointless': 1.0, 'touching': 1.0, 'emptiness': 1.0, 'woven': 1.0, 'cruel': 1.0, 'historically': 1.0, 'wisdom': 1.0, 'fluid': 1.0, 'seal': 1.0, 'casts': 1.0, 'masterpiece': 1.0, 'hopeless': 1.0, 'clumsy': 1.0, 'conviction': 0.9846153846153847, 'realistic': 1.0, 'portrayal': 1.0, 'reveals': 1.0, 'uneven': 0.9880952380952381, 'unpredictable': 1.0, 'epic': 1.0, 'considerable': 1.0, 'enables': 1.0, 'flashes': 1.0, 'vicious': 1.0, 'jagged': 1.0, 'slick': 1.0, 'essentially': 1.0, 'haunting': 1.0, 'pale': 1.0, 'affecting': 1.0, 'intelligent': 0.9914893617021276, 'backward': 1.0, 'thrill': 1.0, 'powerful': 1.0, 'torture': 1.0, 'celebrates': 1.0, 'strongest': 1.0, 'irrelevant': 1.0, 'canvas': 1.0, 'smug': 1.0, 'captures': 1.0, 'offensive': 1.0, 'tale': 0.9943342776203966, 'sitcom': 1.0, 'abuse': 1.0, 'suffers': 1.0, 'drown': 1.0, 'enduring': 1.0, 'acid': 1.0, 'meaningful': 1.0, 'juvenile': 1.0, 'portrait': 1.0, 'compassion': 1.0, 'imitation': 1.0, 'bleak': 1.0, 'convincing': 0.9900990099009901, 'affection': 1.0, 'kills': 1.0, 'courage': 1.0, 'meditation': 1.0, 'universal': 1.0, 'awkwardly': 1.0, 'detached': 1.0, 'clever': 1.0, 'faithful': 1.0, 'exaggerated': 1.0, 'capable': 1.0, 'daring': 1.0, 'emerge': 1.0, 'deadly': 1.0, 'striking': 0.9879518072289156, 'dramatically': 1.0, 'longest': 1.0, 'skill': 1.0, 'fierce': 1.0, 'fallen': 1.0, 'drain': 1.0, 'remarkably': 1.0, 'nausea': 1.0, 'brightly': 1.0, 'playful': 1.0, 'tremendous': 1.0, 'acute': 1.0, 'absorbing': 1.0, 'qualities': 1.0, 'gripping': 1.0, 'startling': 1.0, 'fatal': 1.0, 'glossy': 0.9545454545454546, 'rises': 0.9722222222222222, 'achievement': 1.0, 'graceful': 1.0, 'frantic': 1.0, 'amusing': 0.9957983193277311, 'stirring': 1.0, 'builds': 1.0, 'flourish': 1.0, 'touched': 0.9714285714285714, 'problematic': 0.967741935483871, 'drains': 1.0, 'magnetic': 1.0, 'monstrous': 1.0, 'breathe': 1.0, 'asleep': 1.0, 'borrowed': 1.0, 'creates': 0.9838709677419355, 'expresses': 1.0, 'inactive': 1.0, 'establishes': 1.0, 'feast': 1.0, 'lavish': 1.0, 'reduces': 1.0, 'sympathetic': 1.0, 'clarity': 1.0, 'chuckle': 1.0, 'commanding': 1.0, 'fabricated': 1.0, 'uneasy': 1.0, 'precisely': 1.0, 'stalls': 1.0, 'jerking': 1.0, 'harmless': 1.0, 'adequately': 1.0, 'eerie': 1.0, 'insulting': 1.0, 'racist': 1.0, 'confident': 0.975, 'hollow': 1.0, 'sensation': 1.0, 'sincerity': 0.967741935483871, 'sensual': 1.0, 'cerebral': 1.0, 'glued': 1.0, 'reflective': 1.0, 'snaps': 1.0, 'viewed': 1.0, 'credible': 1.0, 'combines': 0.9545454545454546, 'corpse': 1.0, 'wins': 1.0, 'lifts': 1.0, 'shorter': 1.0, 'refuses': 0.9545454545454546, 'elaborate': 0.967741935483871, 'bravery': 1.0, 'spontaneous': 1.0, 'quietly': 0.9818181818181818, 'portrays': 1.0, 'profound': 1.0, 'dubious': 1.0, 'hampered': 1.0, 'niche': 1.0, 'slack': 1.0, 'vital': 1.0, 'sweetly': 1.0, 'infectious': 1.0, 'conspicuous': 1.0, 'thud': 1.0, 'represents': 1.0, 'exploitation': 1.0, 'triumph': 1.0, 'spends': 1.0, 'breakthrough': 1.0, 'unmistakable': 1.0, 'capture': 1.0, 'penetrating': 1.0, 'fascination': 1.0, 'economical': 1.0, 'costly': 1.0, 'tuned': 1.0, 'displays': 1.0, 'padded': 0.9090909090909091, 'propaganda': 1.0, 'directorial': 1.0, 'repeated': 1.0, 'misery': 1.0, 'willingness': 1.0, 'pity': 1.0, 'wears': 0.9285714285714286, 'assurance': 1.0, 'impact': 0.9859154929577465, 'sly': 1.0, 'emerges': 1.0, 'static': 1.0, 'photographed': 1.0, 'arbitrary': 1.0, 'riot': 1.0, 'loosely': 1.0, 'honesty': 1.0, 'dreadful': 1.0, 'elephant': 1.0, 'approaches': 1.0, 'straining': 1.0, 'translate': 1.0, 'lowered': 1.0, 'disgust': 1.0, 'slip': 1.0, 'stylized': 1.0, 'fires': 1.0, 'utilizing': 1.0, 'pollution': 1.0, 'achieving': 1.0, 'profile': 1.0, 'intensely': 1.0, 'loser': 1.0, 'gently': 1.0, 'stretched': 1.0, 'honorable': 1.0, 'symbolic': 1.0, 'freedom': 1.0, 'weary': 1.0, 'whale': 1.0, 'pr ...
# {'superficial': 0.7520547945205479, 'depressed': 0.9705882352941176, 'redundant': 1.0, 'succeeds': 0.8845070422535212, 'crude': 0.8040816326530612, 'oblivious': 0.68, 'sharply': 0.98, 'recycled': 0.10526315789473684, 'proves': 0.7156028368794326, 'vivid': 0.9746835443037974, 'pointless': 0.9903225806451613, 'touching': 0.9691011235955056, 'emptiness': 0.992, 'woven': 0.9923076923076923, 'cruel': 0.6859649122807018, 'historically': 0.9241379310344827, 'wisdom': 0.9473684210526315, 'fluid': 0.9678571428571429, 'seal': 0.6, 'casts': 0.04285714285714286, 'masterpiece': 0.7111111111111111, 'hopeless': 0.9705882352941176, 'clumsy': 0.9192307692307692, 'conviction': 0.6938461538461539, 'realistic': 0.8846153846153846, 'portrayal': 0.9777777777777777, 'reveals': 0.8953846153846153, 'uneven': 0.844047619047619, 'unpredictable': 0.958, 'epic': 0.7990291262135922, 'considerable': 0.7961165048543689, 'enables': 1.0, 'flashes': 1.0, 'vicious': 1.0, 'jagged': 0.99375, 'slick': 0.228, 'essentially': 0.7314814814814815, 'haunting': 0.875438596491228, 'pale': 0.5484633569739953, 'affecting': 0.9346938775510204, 'intelligent': 0.8276595744680851, 'backward': 0.7875, 'thrill': 0.9763157894736842, 'powerful': 0.9699152542372881, 'torture': 0.9257142857142857, 'celebrates': 1.0, 'strongest': 0.945, 'irrelevant': 0.945, 'canvas': 0.9611111111111111, 'smug': 0.9404761904761905, 'captures': 0.9703296703296703, 'offensive': 0.94875, 'tale': 0.7926345609065156, 'sitcom': 0.575, 'abuse': 0.75, 'suffers': 0.96, 'drown': 0.9961538461538462, 'enduring': 0.9827586206896551, 'acid': 0.95, 'meaningful': 0.7441860465116279, 'juvenile': 0.1918918918918919, 'portrait': 0.9643617021276596, 'compassion': 0.9093023255813953, 'imitation': 0.9676470588235294, 'bleak': 0.7909090909090909, 'convincing': 0.7366336633663366, 'affection': 0.5888888888888889, 'kills': 1.0, 'courage': 0.9531914893617022, 'meditation': 0.932, 'universal': 0.9123287671232877, 'awkwardly': 0.9391304347826087, 'detached': 0.9578947368421052, 'clever': 0.7215686274509804, 'faithful': 0.9325, 'exaggerated': 0.7375, 'capable': 0.3952380952380952, 'daring': 0.7488372093023256, 'emerge': 0.8484848484848485, 'deadly': 0.11372549019607843, 'striking': 0.9710843373493976, 'dramatically': 0.12903225806451613, 'longest': 0.15555555555555556, 'skill': 0.7583333333333333, 'fierce': 0.7878787878787878, 'fallen': 0.4166666666666667, 'drain': 0.8833333333333333, 'remarkably': 0.8728395061728395, 'nausea': 1.0, 'brightly': 0.8571428571428571, 'playful': 0.9265060240963855, 'tremendous': 0.921875, 'acute': 0.9533333333333334, 'absorbing': 0.9181818181818182, 'qualities': 0.6772727272727272, 'gripping': 0.8527027027027027, 'startling': 0.995, 'fatal': 0.8166666666666667, 'glossy': 0.2772727272727273, 'rises': 0.48333333333333334, 'achievement': 0.8047619047619048, 'graceful': 0.5482758620689655, 'frantic': 0.9928571428571429, 'amusing': 0.7147058823529412, 'stirring': 0.9023809523809524, 'builds': 1.0, 'flourish': 1.0, 'touched': 0.7142857142857143, 'problematic': 0.5290322580645161, 'drains': 0.8214285714285714, 'magnetic': 0.9571428571428572, 'monstrous': 0.8631578947368421, 'breathe': 0.8, 'asleep': 0.9428571428571428, 'borrowed': 0.9871794871794872, 'creates': 0.9451612903225807, 'expresses': 1.0, 'inactive': 0.7333333333333333, 'establishes': 0.9923076923076923, 'feast': 1.0, 'lavish': 0.8823529411764706, 'reduces': 0.95, 'sympathetic': 1.0, 'clarity': 0.905, 'chuckle': 0.9238095238095239, 'commanding': 0.9666666666666667, 'fabricated': 0.9461538461538461, 'uneasy': 0.73, 'precisely': 0.7222222222222222, 'stalls': 0.9545454545454546, 'jerking': 0.7538461538461538, 'harmless': 0.3526315789473684, 'adequately': 0.875, 'eerie': 0.856, 'insulting': 1.0, 'racist': 0.27647058823529413, 'confident': 0.955, 'hollow': 0.925, 'sensation': 0.425, 'sincerity': 0.7096774193548387, 'sensual': 1.0, 'cerebral': 0.9846153846153847, 'glued': 0.3333333333333333, 'reflective': 1.0, 'snaps': 0.66, 'viewed': 1.0, 'credible': 0.6 ...

# %%
acc_diff = dict()
for k in ori_acc:
    acc_diff[k] = abs(ori_acc[k] - generated_acc[k])
    

for idx, (k, v) in enumerate(acc_diff.items()):
    if v < 0.3:
        continue
    print("{}\t{:.2f}\t{:.2f}\t{:.2f}\t{}".format(k, v, ori_acc[k], 
                                                  generated_acc[k], ",".join(syns[k][:3])))
# Out:
# oblivious	0.32	1.00	0.68	insensitive,uncaring,unsympathetic
# recycled	0.89	1.00	0.11	recycle,recycling,recycles
# cruel	0.31	1.00	0.69	brutal,brutish,ruthless
# seal	0.40	1.00	0.60	sealed,hermetic,stamped
# casts	0.96	1.00	0.04	castings,throws,puts
# slick	0.77	1.00	0.23	blot,blemish,spot
# pale	0.45	1.00	0.55	bali,faint,livid
# sitcom	0.43	1.00	0.57	comic,sitcoms,comedian
# juvenile	0.81	1.00	0.19	juveniles,underage,minors
# affection	0.41	1.00	0.59	tenderness,fondness,ailment
# capable	0.60	1.00	0.40	able,ability,capacity
# deadly	0.89	1.00	0.11	mortal,fatal,lethal
# dramatically	0.87	1.00	0.13	drastically,markedly,significantly
# longest	0.84	1.00	0.16	tallest,longer,most
# fallen	0.58	1.00	0.42	declined,fell,shrunk
# qualities	0.32	1.00	0.68	qualifications,qualification,attributes
# glossy	0.68	0.95	0.28	shiny,lustrous,gloss
# rises	0.49	0.97	0.48	rise,soars,soar
# graceful	0.45	1.00	0.55	elegant,tasteful,courtesy
# problematic	0.44	0.97	0.53	difficult,tricky,challenging
# harmless	0.65	1.00	0.35	inoffensive,innocuous,benign
# racist	0.72	1.00	0.28	racial,ethnic,racially
# sensation	0.57	1.00	0.42	feeling,sense,sentiment
# glued	0.67	1.00	0.33	pasted,stuck,paste
# snaps	0.34	1.00	0.66	snapshots,snapshot,instantaneous
# credible	0.33	1.00	0.67	believable,dependable,reliable
# corpse	0.39	1.00	0.61	cadaver,body,bodies
# wins	0.50	1.00	0.50	win,winning,triumphs
# dubious	0.81	1.00	0.19	questionable,doubtful,debatable
# vital	0.56	1.00	0.44	crucial,essential,key
# represents	0.65	1.00	0.35	constitutes,reflects,poses
# propaganda	0.35	1.00	0.65	publicity,promotional,advocacy
# impact	0.32	0.99	0.66	influences,influence,influenced
# riot	0.59	1.00	0.41	rioting,mutiny,riots
# translate	0.86	1.00	0.14	translating,translated,converting
# lowered	0.50	1.00	0.50	reduced,downsized,reducing
# fires	0.53	1.00	0.47	blazes,wildfire,flames
# pollution	0.69	1.00	0.31	contamination,polluting,contaminated
# weary	0.62	1.00	0.38	fatigued,tired,knackered
# prejudice	0.69	1.00	0.31	prejudices,detriment,harm
# flatly	0.39	1.00	0.61	roundly,categorically,emphatically
# phenomenon	0.46	1.00	0.54	phenomena,occurrence,problem
# emphasizes	0.55	1.00	0.45	stresses,underlines,highlights
# scarcely	0.40	0.93	0.53	barely,hardly,almost
# effectively	0.84	1.00	0.16	efficiently,efficacy,efficient
# knockout	0.39	1.00	0.61	manu,canon,hottie
# liability	0.53	1.00	0.47	accountability,responsibility,responsibilities
